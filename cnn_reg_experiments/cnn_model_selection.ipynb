# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

from tqdm import tqdm

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import regularizers
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from PIL import Image, ImageFile

from sklearn.model_selection import KFold
from sklearn.base import BaseEstimator
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, make_scorer

#This is to handle corrupted images
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
#Nesting the directory because of the way the generator works
data_dir = os.path.join('..', 'data', 'scored')
labels_dir = os.path.join('..', 'data', 'scored.csv')
test_dir = os.path.join('.', 'data', 'val')

#This is used later with the batch size
num_train_imgs = len(os.listdir(data_dir))
num_test_imgs = len(os.listdir(os.path.join(test_dir,'query')))

#Just checking that no images are lost on the way
print("number of training images: ", num_train_imgs)
print("number of test images: ", num_test_imgs)

#Getting the indices in order of appearance from the directory and adding png for the generator
scores_df = pd.read_csv(labels_dir)
scores_df.reset_index(drop=True, inplace=True)
scores_df = scores_df.sort_values(by=['Id'])
scores_df['Id'] = scores_df['Id'].astype(str)+'.png'
scores_df
# Out:
# number of training images:  9600
# number of test images:  1200
#                Id    Actual
# 9264  1002900.png  2.631728
# 3920  1003620.png  1.560731
# 6953  1005208.png  3.137059
# 7129  1005849.png  3.509851
# 2528  1006237.png  1.371129
# ...           ...       ...
# 7083  9997019.png  1.561584
# 8160  9997923.png  3.291464
# 2776  9998327.png  0.971399
# 5146  9998462.png  1.890028
# 4739  9999837.png  0.000839
#
# [9600 rows x 2 columns]

# %%
#Setting parameters
IMG_HEIGHT = 150
IMG_WIDTH = 150

# %%
#scaling values to get intensity between 0 and 1
train_image_generator = ImageDataGenerator(rescale=1./255) # Generator for our training data
validation_image_generator = ImageDataGenerator(rescale=1./255) # Generator for our validation data

# %%
#Generator for our training data, it's being pulled from the dataframe
train_data_gen = train_image_generator.flow_from_dataframe(dataframe=scores_df, directory=data_dir, 
                                              x_col="Id", y_col="Actual", has_ext=True, 
                                              class_mode="other", target_size=(IMG_WIDTH, IMG_HEIGHT), 
                                              batch_size=1)
# Out:
# Found 9600 validated image filenames.

# %%
train_X = ([])
train_y = ([])

for i in tqdm(range(len(train_data_gen))):
    (x,y) = train_data_gen[i]
    train_X.append(x)
    train_y.append(y)

    
train_y = np.asarray(train_y).reshape(-1)
train_X = np.asarray(train_X).reshape(-1,150,150,3)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 9600/9600 [03:54<00:00, 40.98it/s]

# %%
def cnn(dropout=0.2, conv_layer_sizes=[16,32], dense_layer_size=128, batch_norm=True, l2_reg=0.001):
    model = Sequential()
    model.add(Conv2D(conv_layer_sizes[0], 3,padding='same', activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH ,3) ))
    model.add(MaxPooling2D())
    if batch_norm:
        model.add(BatchNormalization())
    model.add(Dropout(dropout))
    model.add(Conv2D(conv_layer_sizes[1], 3,padding='same', activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH ,3) ))
    model.add(MaxPooling2D())
    if batch_norm:
        model.add(BatchNormalization())
    model.add(Dropout(dropout))
    model.add(Flatten())
    model.add(Dense(dense_layer_size, activation='relu', kernel_regularizer=regularizers.l2(l2_reg)))
    if batch_norm:
        model.add(BatchNormalization())
    model.add(Dropout(dropout))
    model.add(Dense(1, activation='linear'))
    return model

# %%
class customCNN(BaseEstimator):
    def __init__(self, epochs=10, batch_size=16, dropout=0.2, 
                   conv_layer_sizes=[16,32], dense_layer_size=128, batch_norm=True, l2_reg=0.001):
        self.epochs = epochs
        self.batch_size = batch_size
        self.dropout = dropout
        self.conv_layer_sizes = conv_layer_sizes
        self.dense_layer_size = dense_layer_size
        self.batch_norm = batch_norm
        self.l2_reg = l2_reg
    
    def fit(self, train_X, train_y, **kwargs):
        self.build_model()
        self.model.fit(train_X, train_y, epochs=self.epochs, batch_size=self.batch_size)
        
    def predict(self, eval_X):
        return self.model.predict(eval_X)
        
    def set_params(self, epochs=10, batch_size=16, dropout=0.2, 
                   conv_layer_sizes=[16,32], dense_layer_size=128, batch_norm=True, l2_reg=0.001):
        self.epochs = epochs
        self.batch_size = batch_size
        self.dropout = dropout
        self.conv_layer_sizes = conv_layer_sizes
        self.dense_layer_size = dense_layer_size
        self.batch_norm = batch_norm
        self.l2_reg = l2_reg
        
        return self
    
    
    def build_model(self):
        self.model = cnn(dropout=self.dropout, conv_layer_sizes=self.conv_layer_sizes, 
                         dense_layer_size=self.dense_layer_size, batch_norm=self.batch_norm, l2_reg=self.l2_reg)
        self.model.compile(loss='MAE', optimizer='adam', metrics=['MSE'])

# %%
params = {
    'epochs': [25, 40],
    'batch_size': [32],
    'dropout': [0.2, 0.4],
    'l2_reg' : [0.001,0.01],
    'conv_layer_sizes': [[16, 16], [32, 32]],
    'dense_layer_size': [64,128],
    'batch_norm': [True, False]
}

dummy_params = {
    'epochs': [25],
    'batch_size': [32],
    'dropout': [0.2],
    'l2_reg' : [0.01],
    'conv_layer_sizes': [[16, 16]],
    'dense_layer_size': [64],
    'batch_norm': [True]
}

model = customCNN()
search2 = GridSearchCV(estimator=model, 
                      param_grid=params,
                      cv=3,
                      scoring=make_scorer(mean_absolute_error),
                      return_train_score=True, 
                      refit=True, verbose=10, n_jobs=1)
best2 = search2.fit(train_X, train_y)
best2.__dict__
# Out:
# Fitting 3 folds for each of 64 candidates, totalling 192 fits
# [CV] batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.2, epochs=25, l2_reg=0.001
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Train on 6400 samples
# Epoch 1/25
# 6400/6400 [==============================] - 6s 989us/sample - loss: 1.2544 - MSE: 2.5177
# Epoch 2/25
# 6400/6400 [==============================] - 3s 500us/sample - loss: 0.9506 - MSE: 1.3201
# Epoch 3/25
# 6400/6400 [==============================] - 3s 502us/sample - loss: 0.8950 - MSE: 1.1674
# Epoch 4/25
# 6400/6400 [==============================] - 3s 501us/sample - loss: 0.8724 - MSE: 1.0848
# Epoch 5/25
# 6400/6400 [==============================] - 3s 505us/sample - loss: 0.8345 - MSE: 1.0070
# Epoch 6/25
# 6400/6400 [==============================] - 3s 499us/sample - loss: 0.8075 - MSE: 0.9547
# Epoch 7/25
# 6400/6400 [==============================] - 3s 505us/sample - loss: 0.7871 - MSE: 0.9010
# Epoch 8/25
# 6400/6400 [==============================] - 3s 499us/sample - loss: 0.7647 - MSE: 0.8724
# Epoch 9/25
# 6400/6400 [==============================] - 3s 498us/sample - loss: 0.7399 - MSE: 0.8090
# Epoch 10/25
# 6400/6400 [==============================] - 3s 501us/sample - loss: 0.7244 - MSE: 0.7925s -
# Epoch 11/25
# 6400/6400 [==============================] - 3s 500us/sample - loss: 0.7206 - MSE: 0.7494
# Epoch 12/25
# 6400/6400 [==============================] - 3s 504us/sample - loss: 0.7135 - MSE: 0.7302
# Epoch 13/25
# 6400/6400 [==============================] - 3s 502us/sample - loss: 0.6945 - MSE: 0.6861
# Epoch 14/25
# 6400/6400 [==============================] - 3s 518us/sample - loss: 0.6829 - MSE: 0.6690
# Epoch 15/25
# 6400/6400 [==============================] - 3s 511us/sample - loss: 0.6824 - MSE: 0.6591
# Epoch 16/25
# 6400/6400 [==============================] - 3s 506us/sample - loss: 0.6738 - MSE: 0.6214
# Epoch 17/25
# 6400/6400 [==============================] - 3s 508us/sample - loss: 0.6768 - MSE: 0.6221
# Epoch 18/25
# 6400/6400 [==============================] - 3s 508us/sample - loss: 0.6563 - MSE: 0.5830
# Epoch 19/25
# 6400/6400 [==============================] - 3s 521us/sample - loss: 0.6509 - MSE: 0.5780
# Epoch 20/25
# 6400/6400 [==============================] - 3s 508us/sample - loss: 0.6462 - MSE: 0.5698
# Epoch 21/25
# 6400/6400 [==============================] - 3s 506us/sample - loss: 0.6478 - MSE: 0.5602
# Epoch 22/25
# 6400/6400 [==============================] - 3s 509us/sample - loss: 0.6467 - MSE: 0.5418
# Epoch 23/25
# 6400/6400 [==============================] - 3s 510us/sample - loss: 0.6393 - MSE: 0.5158
# Epoch 24/25
# 6400/6400 [==============================] - 3s 511us/sample - loss: 0.6424 - MSE: 0.5179
# Epoch 25/25
# 6400/6400 [==============================] - 3s 508us/sample - loss: 0.6368 - MSE: 0.5168s - loss: 0.63
# [CV]  batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.2, epochs=25, l2_reg=0.001, score=(train=0.791, test=0.850), total= 1.5min
# [CV] batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.2, epochs=25, l2_reg=0.001
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.5min remaining:    0.0s
# Train on 6400 samples
# Epoch 1/25
# 6400/6400 [==============================] - 4s 703us/sample - loss: 1.2317 - MSE: 2.4194
# Epoch 2/25
# 6400/6400 [==============================] - 3s 510us/sample - loss: 0.9157 - MSE: 1.2321s - loss: 0.9164 - MSE: 1.2
# Epoch 3/25
# 6400/6400 [==============================] - 3s 509us/sample - loss: 0.8664 - MSE: 1.1406
# Epoch 4/25
# 6400/6400 [==============================] - 3s 508us/sample - loss: 0.8275 - MSE: 1.0778
# Epoch 5/25
# 6400/6400 [==============================] - 3s 509us/sample - loss: 0.7979 - MSE: 0.9970s - loss: 0.7928 -
# Epoch 6/25
# 6400/6400 [==============================] - 3s 513us/sample - loss: 0.7803 - MSE: 0.9438
# Epoch 7/25
# 6400/6400 [==============================] - 3s 523us/sample - loss: 0.7663 - MSE: 0.9106
# Epoch 8/25
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.7471 - MSE: 0.8761
# Epoch 9/25
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.7432 - MSE: 0.8337
# Epoch 10/25
# 6400/6400 [==============================] - 3s 516us/sample - loss: 0.7301 - MSE: 0.7723
# Epoch 11/25
# 6400/6400 [==============================] - 3s 510us/sample - loss: 0.7254 - MSE: 0.7433
# Epoch 12/25
# 6400/6400 [==============================] - 3s 509us/sample - loss: 0.7214 - MSE: 0.7199
# Epoch 13/25
# 6400/6400 [==============================] - 3s 512us/sample - loss: 0.6941 - MSE: 0.6668
# Epoch 14/25
# 6400/6400 [==============================] - 3s 512us/sample - loss: 0.6860 - MSE: 0.6499
# Epoch 15/25
# 6400/6400 [==============================] - 3s 512us/sample - loss: 0.6651 - MSE: 0.6126
# Epoch 16/25
# 6400/6400 [==============================] - 3s 513us/sample - loss: 0.6901 - MSE: 0.6263
# Epoch 17/25
# 6400/6400 [==============================] - 3s 509us/sample - loss: 0.6709 - MSE: 0.5870
# Epoch 18/25
# 6400/6400 [==============================] - 3s 511us/sample - loss: 0.6544 - MSE: 0.5686
# Epoch 19/25
# 6400/6400 [==============================] - 3s 510us/sample - loss: 0.6573 - MSE: 0.5511
# Epoch 20/25
# 6400/6400 [==============================] - 3s 508us/sample - loss: 0.6435 - MSE: 0.5420
# Epoch 21/25
# 6400/6400 [==============================] - 3s 512us/sample - loss: 0.6446 - MSE: 0.5424
# Epoch 22/25
# 6400/6400 [==============================] - 3s 510us/sample - loss: 0.6356 - MSE: 0.5432
# Epoch 23/25
# 6400/6400 [==============================] - 3s 509us/sample - loss: 0.6321 - MSE: 0.5167
# Epoch 24/25
# 6400/6400 [==============================] - 3s 511us/sample - loss: 0.6339 - MSE: 0.5233
# Epoch 25/25
# 6400/6400 [==============================] - 3s 510us/sample - loss: 0.6171 - MSE: 0.4962
# [CV]  batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.2, epochs=25, l2_reg=0.001, score=(train=1.117, test=1.182), total= 1.4min
# [CV] batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.2, epochs=25, l2_reg=0.001
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  3.0min remaining:    0.0s
# Train on 6400 samples
# Epoch 1/25
# 6400/6400 [==============================] - 5s 708us/sample - loss: 1.2452 - MSE: 2.5459
# Epoch 2/25
# 6400/6400 [==============================] - 3s 512us/sample - loss: 0.9301 - MSE: 1.2947
# Epoch 3/25
# 6400/6400 [==============================] - 3s 538us/sample - loss: 0.8885 - MSE: 1.2135s - loss: 0.8980 - ETA: 0s - loss: 0.8921 - MSE:
# Epoch 4/25
# 6400/6400 [==============================] - 3s 540us/sample - loss: 0.8259 - MSE: 1.0198
# Epoch 5/25
# 6400/6400 [==============================] - 3s 537us/sample - loss: 0.8069 - MSE: 0.9920
# Epoch 6/25
# 6400/6400 [==============================] - 3s 511us/sample - loss: 0.7768 - MSE: 0.9136
# Epoch 7/25
# 6400/6400 [==============================] - 3s 512us/sample - loss: 0.7699 - MSE: 0.8758s - loss: 0.7675 - MSE: 0.
# Epoch 8/25
# 6400/6400 [==============================] - 3s 512us/sample - loss: 0.7823 - MSE: 0.9103
# Epoch 9/25
# 6400/6400 [==============================] - 3s 522us/sample - loss: 0.7553 - MSE: 0.8310
# Epoch 10/25
# 6400/6400 [==============================] - 3s 512us/sample - loss: 0.7337 - MSE: 0.7984s - l
# Epoch 11/25
# 6400/6400 [==============================] - 3s 508us/sample - loss: 0.7165 - MSE: 0.7664
# Epoch 12/25
# 6400/6400 [==============================] - 3s 510us/sample - loss: 0.7045 - MSE: 0.7137
# Epoch 13/25
# 6400/6400 [==============================] - 3s 514us/sample - loss: 0.6976 - MSE: 0.6707
# Epoch 14/25
# 6400/6400 [==============================] - 3s 509us/sample - loss: 0.6814 - MSE: 0.6499
# Epoch 15/25
# 6400/6400 [==============================] - 3s 513us/sample - loss: 0.6840 - MSE: 0.6326
# Epoch 16/25
# 6400/6400 [==============================] - 3s 512us/sample - loss: 0.6768 - MSE: 0.6155
# Epoch 17/25
# 6400/6400 [==============================] - 3s 508us/sample - loss: 0.6711 - MSE: 0.5756s - l
# Epoch 18/25
# 6400/6400 [==============================] - 3s 512us/sample - loss: 0.6530 - MSE: 0.5604
# Epoch 19/25
# 6400/6400 [==============================] - 3s 511us/sample - loss: 0.6689 - MSE: 0.5533
# Epoch 20/25
# 6400/6400 [==============================] - 3s 509us/sample - loss: 0.6429 - MSE: 0.5304
# Epoch 21/25
# 6400/6400 [==============================] - 3s 511us/sample - loss: 0.6426 - MSE: 0.5223
# Epoch 22/25
# 6400/6400 [==============================] - 3s 512us/sample - loss: 0.6501 - MSE: 0.5340s -
# Epoch 23/25
# 6400/6400 [==============================] - 3s 505us/sample - loss: 0.6498 - MSE: 0.5149
# Epoch 24/25
# 6400/6400 [==============================] - 3s 509us/sample - loss: 0.6451 - MSE: 0.5182
# Epoch 25/25
# 6400/6400 [==============================] - 3s 509us/sample - loss: 0.6373 - MSE: 0.4902
# [CV]  batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.2, epochs=25, l2_reg=0.001, score=(train=0.955, test=1.037), total= 1.4min
# [CV] batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.2, epochs=25, l2_reg=0.01
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  4.4min remaining:    0.0s
# Train on 6400 samples
# Epoch 1/25
# 6400/6400 [==============================] - 4s 673us/sample - loss: 1.7716 - MSE: 3.2423
# Epoch 2/25
# 6400/6400 [==============================] - 3s 512us/sample - loss: 1.1614 - MSE: 1.3179
# Epoch 3/25
# 6400/6400 [==============================] - 3s 509us/sample - loss: 1.0375 - MSE: 1.1837
# Epoch 4/25
# 6400/6400 [==============================] - 3s 511us/sample - loss: 0.9747 - MSE: 1.1423
# Epoch 5/25
# 6400/6400 [==============================] - 3s 513us/sample - loss: 0.9310 - MSE: 1.0701
# Epoch 6/25
# 6400/6400 [==============================] - 3s 517us/sample - loss: 0.9219 - MSE: 1.0686
# Epoch 7/25
# 6400/6400 [==============================] - 3s 516us/sample - loss: 0.9143 - MSE: 1.0175
# Epoch 8/25
# 6400/6400 [==============================] - 3s 511us/sample - loss: 0.9361 - MSE: 0.9582
# Epoch 9/25
# 6400/6400 [==============================] - 3s 534us/sample - loss: 0.8890 - MSE: 0.8994
# Epoch 10/25
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.9275 - MSE: 0.9298
# Epoch 11/25
# 6400/6400 [==============================] - 3s 518us/sample - loss: 0.9422 - MSE: 0.8888
# Epoch 12/25
# 6400/6400 [==============================] - 3s 522us/sample - loss: 0.9248 - MSE: 0.8743
# Epoch 13/25
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.9088 - MSE: 0.8729
# Epoch 14/25
# 6400/6400 [==============================] - 3s 522us/sample - loss: 0.8913 - MSE: 0.8523
# Epoch 15/25
# 6400/6400 [==============================] - 3s 523us/sample - loss: 0.9191 - MSE: 0.8335
# Epoch 16/25
# 6400/6400 [==============================] - 3s 522us/sample - loss: 0.9784 - MSE: 0.8345
# Epoch 17/25
# 6400/6400 [==============================] - 3s 521us/sample - loss: 0.8980 - MSE: 0.8186
# Epoch 18/25
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.8793 - MSE: 0.8024
# Epoch 19/25
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.9386 - MSE: 0.7889
# Epoch 20/25
# 6400/6400 [==============================] - 3s 523us/sample - loss: 0.9372 - MSE: 0.8165
# Epoch 21/25
# 6400/6400 [==============================] - 3s 522us/sample - loss: 0.9410 - MSE: 0.7876
# Epoch 22/25
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8606 - MSE: 0.7846
# Epoch 23/25
# 6400/6400 [==============================] - 3s 521us/sample - loss: 0.8346 - MSE: 0.7608
# Epoch 24/25
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.8804 - MSE: 0.7687
# Epoch 25/25
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.8883 - MSE: 0.7449
# [CV]  batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.2, epochs=25, l2_reg=0.01, score=(train=0.840, test=0.884), total= 1.4min
# [CV] batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.2, epochs=25, l2_reg=0.01
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  5.9min remaining:    0.0s
# Train on 6400 samples
# Epoch 1/25
# 6400/6400 [==============================] - 4s 693us/sample - loss: 1.7916 - MSE: 2.5714
# Epoch 2/25
# 6400/6400 [==============================] - 3s 521us/sample - loss: 1.1405 - MSE: 1.2836
# Epoch 3/25
# 6400/6400 [==============================] - 3s 519us/sample - loss: 1.0455 - MSE: 1.2254
# Epoch 4/25
# 6400/6400 [==============================] - 3s 517us/sample - loss: 0.9904 - MSE: 1.1402
# Epoch 5/25
# 6400/6400 [==============================] - 3s 521us/sample - loss: 0.9592 - MSE: 1.0205
# Epoch 6/25
# 6400/6400 [==============================] - 3s 522us/sample - loss: 0.9106 - MSE: 0.9846
# Epoch 7/25
# 6400/6400 [==============================] - 3s 522us/sample - loss: 0.8474 - MSE: 0.9794
# Epoch 8/25
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8774 - MSE: 0.9567
# Epoch 9/25
# 6400/6400 [==============================] - 3s 523us/sample - loss: 0.8399 - MSE: 0.9120
# Epoch 10/25
# 6400/6400 [==============================] - 3s 523us/sample - loss: 0.8300 - MSE: 0.8968
# Epoch 11/25
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8725 - MSE: 0.9179
# Epoch 12/25
# 6400/6400 [==============================] - 3s 522us/sample - loss: 0.8633 - MSE: 0.8713
# Epoch 13/25
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8600 - MSE: 0.8699
# Epoch 14/25
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.8505 - MSE: 0.8542s - loss: 0.8529
# Epoch 15/25
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8262 - MSE: 0.8421
# Epoch 16/25
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.8645 - MSE: 0.8481
# Epoch 17/25
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8455 - MSE: 0.8331
# Epoch 18/25
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.8604 - MSE: 0.8264
# Epoch 19/25
# 6400/6400 [==============================] - 3s 530us/sample - loss: 0.8316 - MSE: 0.8191
# Epoch 20/25
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.8531 - MSE: 0.8073
# Epoch 21/25
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.8180 - MSE: 0.8193
# Epoch 22/25
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8068 - MSE: 0.7915
# Epoch 23/25
# 6400/6400 [==============================] - 3s 535us/sample - loss: 0.8368 - MSE: 0.7827
# Epoch 24/25
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.8407 - MSE: 0.7874
# Epoch 25/25
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8444 - MSE: 0.7732
# [CV]  batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.2, epochs=25, l2_reg=0.01, score=(train=0.861, test=0.890), total= 1.5min
# [CV] batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.2, epochs=25, l2_reg=0.01
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  7.4min remaining:    0.0s
# Train on 6400 samples
# Epoch 1/25
# 6400/6400 [==============================] - 5s 735us/sample - loss: 1.7088 - MSE: 2.3459
# Epoch 2/25
# 6400/6400 [==============================] - 3s 524us/sample - loss: 1.1130 - MSE: 1.3063
# Epoch 3/25
# 6400/6400 [==============================] - 3s 525us/sample - loss: 1.0319 - MSE: 1.1353
# Epoch 4/25
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.9750 - MSE: 1.0724
# Epoch 5/25
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.9082 - MSE: 1.0099
# Epoch 6/25
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.8992 - MSE: 0.9754
# Epoch 7/25
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.8881 - MSE: 0.9934
# Epoch 8/25
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.8901 - MSE: 0.9459
# Epoch 9/25
# 6400/6400 [==============================] - 3s 523us/sample - loss: 0.8741 - MSE: 0.9087
# Epoch 10/25
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.8363 - MSE: 0.9128
# Epoch 11/25
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.8498 - MSE: 0.8909
# Epoch 12/25
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.8551 - MSE: 0.8646
# Epoch 13/25
# 6400/6400 [==============================] - 3s 523us/sample - loss: 0.8252 - MSE: 0.8566
# Epoch 14/25
# 6400/6400 [==============================] - 3s 531us/sample - loss: 0.8618 - MSE: 0.8575
# Epoch 15/25
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.8398 - MSE: 0.8386
# Epoch 16/25
# 6400/6400 [==============================] - 3s 531us/sample - loss: 0.8110 - MSE: 0.8197
# Epoch 17/25
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8385 - MSE: 0.8280
# Epoch 18/25
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.8913 - MSE: 0.8302s -
# Epoch 19/25
# 6400/6400 [==============================] - 3s 531us/sample - loss: 0.9315 - MSE: 0.8297
# Epoch 20/25
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.9148 - MSE: 0.8518
# Epoch 21/25
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.9311 - MSE: 0.8529
# Epoch 22/25
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8650 - MSE: 0.8367
# Epoch 23/25
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.8905 - MSE: 0.8291
# Epoch 24/25
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.9242 - MSE: 0.8196
# Epoch 25/25
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8671 - MSE: 0.8236
# [CV]  batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.2, epochs=25, l2_reg=0.01, score=(train=0.685, test=0.700), total= 1.5min
# [CV] batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.2, epochs=40, l2_reg=0.001
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  8.9min remaining:    0.0s
# Train on 6400 samples
# Epoch 1/40
# 6400/6400 [==============================] - 4s 686us/sample - loss: 1.2330 - MSE: 2.5710
# Epoch 2/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.9446 - MSE: 1.4109
# Epoch 3/40
# 6400/6400 [==============================] - 3s 522us/sample - loss: 0.9051 - MSE: 1.2557
# Epoch 4/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8520 - MSE: 1.1301
# Epoch 5/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8278 - MSE: 1.0423
# Epoch 6/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.8075 - MSE: 1.0044
# Epoch 7/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.7945 - MSE: 0.9270
# Epoch 8/40
# 6400/6400 [==============================] - 3s 531us/sample - loss: 0.7866 - MSE: 0.9019
# Epoch 9/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.7699 - MSE: 0.8582
# Epoch 10/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.7749 - MSE: 0.8562
# Epoch 11/40
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.7518 - MSE: 0.7962
# Epoch 12/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.7261 - MSE: 0.7380
# Epoch 13/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.7140 - MSE: 0.7056
# Epoch 14/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.6962 - MSE: 0.6682
# Epoch 15/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.6903 - MSE: 0.6364
# Epoch 16/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.6709 - MSE: 0.6051s - loss
# Epoch 17/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.6807 - MSE: 0.5971
# Epoch 18/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.6685 - MSE: 0.5703
# Epoch 19/40
# 6400/6400 [==============================] - 3s 523us/sample - loss: 0.6625 - MSE: 0.5616
# Epoch 20/40
# 6400/6400 [==============================] - 3s 523us/sample - loss: 0.6725 - MSE: 0.5663
# Epoch 21/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.6526 - MSE: 0.5355
# Epoch 22/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.6486 - MSE: 0.5303
# Epoch 23/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.6486 - MSE: 0.5104
# Epoch 24/40
# 6400/6400 [==============================] - 3s 532us/sample - loss: 0.6463 - MSE: 0.5095
# Epoch 25/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.6288 - MSE: 0.4818
# Epoch 26/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.6145 - MSE: 0.4629
# Epoch 27/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.6233 - MSE: 0.4786
# Epoch 28/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.6196 - MSE: 0.4707
# Epoch 29/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.6172 - MSE: 0.4546
# Epoch 30/40
# 6400/6400 [==============================] - 3s 521us/sample - loss: 0.6156 - MSE: 0.4444
# Epoch 31/40
# 6400/6400 [==============================] - 3s 533us/sample - loss: 0.6112 - MSE: 0.4326
# Epoch 32/40
# 6400/6400 [==============================] - 3s 531us/sample - loss: 0.6155 - MSE: 0.4478
# Epoch 33/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.6134 - MSE: 0.4497
# Epoch 34/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.6078 - MSE: 0.4416
# Epoch 35/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.5960 - MSE: 0.4241
# Epoch 36/40
# 6400/6400 [==============================] - 3s 522us/sample - loss: 0.6007 - MSE: 0.4198
# Epoch 37/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.5960 - MSE: 0.4156
# Epoch 38/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.6077 - MSE: 0.4347
# Epoch 39/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.5879 - MSE: 0.4140
# Epoch 40/40
# 6400/6400 [==============================] - 3s 523us/sample - loss: 0.5997 - MSE: 0.4306
# [CV]  batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.2, epochs=40, l2_reg=0.001, score=(train=1.043, test=1.097), total= 2.3min
# [CV] batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.2, epochs=40, l2_reg=0.001
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed: 11.2min remaining:    0.0s
# Train on 6400 samples
# Epoch 1/40
# 6400/6400 [==============================] - 5s 744us/sample - loss: 1.2190 - MSE: 2.6222
# Epoch 2/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.9449 - MSE: 1.2982
# Epoch 3/40
# 6400/6400 [==============================] - 3s 521us/sample - loss: 0.8842 - MSE: 1.1770
# Epoch 4/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8337 - MSE: 1.0479
# Epoch 5/40
# 6400/6400 [==============================] - 3s 521us/sample - loss: 0.8061 - MSE: 0.9934
# Epoch 6/40
# 6400/6400 [==============================] - 3s 537us/sample - loss: 0.7858 - MSE: 0.9549
# Epoch 7/40
# 6400/6400 [==============================] - 3s 534us/sample - loss: 0.7575 - MSE: 0.8807
# Epoch 8/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.7581 - MSE: 0.8614
# Epoch 9/40
# 6400/6400 [==============================] - 3s 520us/sample - loss: 0.7543 - MSE: 0.8454
# Epoch 10/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.7594 - MSE: 0.8407
# Epoch 11/40
# 6400/6400 [==============================] - 3s 523us/sample - loss: 0.7324 - MSE: 0.7718
# Epoch 12/40
# 6400/6400 [==============================] - 3s 531us/sample - loss: 0.7200 - MSE: 0.7315
# Epoch 13/40
# 6400/6400 [==============================] - 3s 522us/sample - loss: 0.7042 - MSE: 0.7010
# Epoch 14/40
# 6400/6400 [==============================] - 3s 520us/sample - loss: 0.7095 - MSE: 0.7019
# Epoch 15/40
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.6939 - MSE: 0.6487
# Epoch 16/40
# 6400/6400 [==============================] - 3s 522us/sample - loss: 0.6831 - MSE: 0.6237
# Epoch 17/40
# 6400/6400 [==============================] - 3s 523us/sample - loss: 0.6739 - MSE: 0.6044
# Epoch 18/40
# 6400/6400 [==============================] - 3s 522us/sample - loss: 0.6942 - MSE: 0.5993
# Epoch 19/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.6954 - MSE: 0.6055
# Epoch 20/40
# 6400/6400 [==============================] - 3s 522us/sample - loss: 0.6856 - MSE: 0.5782
# Epoch 21/40
# 6400/6400 [==============================] - 3s 523us/sample - loss: 0.6593 - MSE: 0.5309
# Epoch 22/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.6617 - MSE: 0.5234
# Epoch 23/40
# 6400/6400 [==============================] - 3s 520us/sample - loss: 0.6482 - MSE: 0.5086
# Epoch 24/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.6547 - MSE: 0.5133
# Epoch 25/40
# 6400/6400 [==============================] - 3s 522us/sample - loss: 0.6470 - MSE: 0.5080
# Epoch 26/40
# 6400/6400 [==============================] - 3s 523us/sample - loss: 0.6577 - MSE: 0.5096
# Epoch 27/40
# 6400/6400 [==============================] - 3s 523us/sample - loss: 0.6348 - MSE: 0.4883
# Epoch 28/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.6414 - MSE: 0.4994
# Epoch 29/40
# 6400/6400 [==============================] - 3s 533us/sample - loss: 0.6461 - MSE: 0.4899
# Epoch 30/40
# 6400/6400 [==============================] - 3s 538us/sample - loss: 0.6264 - MSE: 0.4591
# Epoch 31/40
# 6400/6400 [==============================] - 3s 533us/sample - loss: 0.6091 - MSE: 0.4401
# Epoch 32/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.6161 - MSE: 0.4481
# Epoch 33/40
# 6400/6400 [==============================] - 3s 530us/sample - loss: 0.6205 - MSE: 0.4421
# Epoch 34/40
# 6400/6400 [==============================] - 3s 530us/sample - loss: 0.6191 - MSE: 0.4518
# Epoch 35/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.6143 - MSE: 0.4406
# Epoch 36/40
# 6400/6400 [==============================] - 3s 522us/sample - loss: 0.5983 - MSE: 0.4185
# Epoch 37/40
# 6400/6400 [==============================] - 3s 522us/sample - loss: 0.6099 - MSE: 0.4339
# Epoch 38/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.6042 - MSE: 0.4267
# Epoch 39/40
# 6400/6400 [==============================] - 3s 530us/sample - loss: 0.6013 - MSE: 0.4179
# Epoch 40/40
# 6400/6400 [==============================] - 3s 536us/sample - loss: 0.5939 - MSE: 0.4239
# [CV]  batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.2, epochs=40, l2_reg=0.001, score=(train=0.765, test=0.988), total= 2.3min
# [CV] batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.2, epochs=40, l2_reg=0.001
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 13.6min remaining:    0.0s
# Train on 6400 samples
# Epoch 1/40
# 6400/6400 [==============================] - 5s 754us/sample - loss: 1.2426 - MSE: 2.3982
# Epoch 2/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.9298 - MSE: 1.2352
# Epoch 3/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.8772 - MSE: 1.1343
# Epoch 4/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.8269 - MSE: 1.0181
# Epoch 5/40
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.7958 - MSE: 0.9452
# Epoch 6/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.7840 - MSE: 0.9104
# Epoch 7/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.7608 - MSE: 0.8750
# Epoch 8/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.7599 - MSE: 0.8549
# Epoch 9/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.7451 - MSE: 0.8459
# Epoch 10/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.7310 - MSE: 0.7778
# Epoch 11/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.7285 - MSE: 0.7540
# Epoch 12/40
# 6400/6400 [==============================] - 3s 530us/sample - loss: 0.7221 - MSE: 0.7213
# Epoch 13/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.7131 - MSE: 0.7246
# Epoch 14/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.7084 - MSE: 0.6903
# Epoch 15/40
# 6400/6400 [==============================] - 3s 534us/sample - loss: 0.6957 - MSE: 0.6722
# Epoch 16/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.7058 - MSE: 0.6791
# Epoch 17/40
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.6868 - MSE: 0.6232
# Epoch 18/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.6804 - MSE: 0.6216
# Epoch 19/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.6623 - MSE: 0.5755
# Epoch 20/40
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.6681 - MSE: 0.5722
# Epoch 21/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.6669 - MSE: 0.5532
# Epoch 22/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.6594 - MSE: 0.5474
# Epoch 23/40
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.6540 - MSE: 0.5479
# Epoch 24/40
# 6400/6400 [==============================] - 3s 534us/sample - loss: 0.6295 - MSE: 0.5234
# Epoch 25/40
# 6400/6400 [==============================] - 3s 539us/sample - loss: 0.6237 - MSE: 0.5182
# Epoch 26/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.6286 - MSE: 0.5092
# Epoch 27/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.6347 - MSE: 0.5106
# Epoch 28/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.6286 - MSE: 0.4875
# Epoch 29/40
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.6235 - MSE: 0.4919
# Epoch 30/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.6154 - MSE: 0.5067
# Epoch 31/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.6142 - MSE: 0.4868
# Epoch 32/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.6106 - MSE: 0.4841
# Epoch 33/40
# 6400/6400 [==============================] - 3s 530us/sample - loss: 0.6006 - MSE: 0.4656
# Epoch 34/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.5963 - MSE: 0.4637
# Epoch 35/40
# 6400/6400 [==============================] - 3s 530us/sample - loss: 0.5954 - MSE: 0.4736
# Epoch 36/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.6081 - MSE: 0.4857
# Epoch 37/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.5949 - MSE: 0.4588
# Epoch 38/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.5994 - MSE: 0.4495
# Epoch 39/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.5997 - MSE: 0.4567
# Epoch 40/40
# 6400/6400 [==============================] - 3s 530us/sample - loss: 0.5929 - MSE: 0.4409
# [CV]  batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.2, epochs=40, l2_reg=0.001, score=(train=0.978, test=1.037), total= 2.3min
# [CV] batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.2, epochs=40, l2_reg=0.01
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed: 15.9min remaining:    0.0s
# Train on 6400 samples
# Epoch 1/40
# 6400/6400 [==============================] - 5s 756us/sample - loss: 1.7749 - MSE: 2.4078
# Epoch 2/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 1.1822 - MSE: 1.4379
# Epoch 3/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 1.0715 - MSE: 1.2492
# Epoch 4/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.9883 - MSE: 1.0978
# Epoch 5/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.9842 - MSE: 1.0863
# Epoch 6/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.9103 - MSE: 1.0511
# Epoch 7/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.9138 - MSE: 1.0171
# Epoch 8/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8932 - MSE: 0.9812
# Epoch 9/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.8689 - MSE: 0.9466
# Epoch 10/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.8752 - MSE: 0.9198
# Epoch 11/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.8763 - MSE: 0.8834
# Epoch 12/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.8905 - MSE: 0.8674
# Epoch 13/40
# 6400/6400 [==============================] - 3s 523us/sample - loss: 0.8630 - MSE: 0.8440
# Epoch 14/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.8775 - MSE: 0.8387
# Epoch 15/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.9426 - MSE: 0.8474
# Epoch 16/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.8974 - MSE: 0.8463
# Epoch 17/40
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.8596 - MSE: 0.8306
# Epoch 18/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.8277 - MSE: 0.8195
# Epoch 19/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8509 - MSE: 0.8098
# Epoch 20/40
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.8673 - MSE: 0.8218
# Epoch 21/40
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.8502 - MSE: 0.8105
# Epoch 22/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8339 - MSE: 0.7821
# Epoch 23/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.8386 - MSE: 0.7993
# Epoch 24/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8422 - MSE: 0.7975
# Epoch 25/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.8142 - MSE: 0.7704s - loss: 0
# Epoch 26/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.8352 - MSE: 0.7689
# Epoch 27/40
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.8547 - MSE: 0.7766
# Epoch 28/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.8794 - MSE: 0.7718
# Epoch 29/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.8830 - MSE: 0.7700
# Epoch 30/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.8854 - MSE: 0.7771
# Epoch 31/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.8102 - MSE: 0.7596
# Epoch 32/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.8039 - MSE: 0.7419
# Epoch 33/40
# 6400/6400 [==============================] - 3s 531us/sample - loss: 0.7927 - MSE: 0.7513
# Epoch 34/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.8040 - MSE: 0.7315
# Epoch 35/40
# 6400/6400 [==============================] - 3s 522us/sample - loss: 0.7863 - MSE: 0.7323
# Epoch 36/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.7802 - MSE: 0.7132
# Epoch 37/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.7730 - MSE: 0.7103
# Epoch 38/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.7911 - MSE: 0.7001
# Epoch 39/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.7636 - MSE: 0.7138
# Epoch 40/40
# 6400/6400 [==============================] - 3s 522us/sample - loss: 0.7817 - MSE: 0.7577
# [CV]  batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.2, epochs=40, l2_reg=0.01, score=(train=4.802, test=4.813), total= 2.3min
# [CV] batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.2, epochs=40, l2_reg=0.01
# Train on 6400 samples
# Epoch 1/40
# 6400/6400 [==============================] - 5s 753us/sample - loss: 1.7710 - MSE: 2.2137
# Epoch 2/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 1.1244 - MSE: 1.2374
# Epoch 3/40
# 6400/6400 [==============================] - 3s 529us/sample - loss: 1.0442 - MSE: 1.1357
# Epoch 4/40
# 6400/6400 [==============================] - 3s 523us/sample - loss: 0.9782 - MSE: 1.0348
# Epoch 5/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.9686 - MSE: 1.0183
# Epoch 6/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.9247 - MSE: 0.9634
# Epoch 7/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8921 - MSE: 0.9489
# Epoch 8/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.8366 - MSE: 0.9036
# Epoch 9/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.8830 - MSE: 0.8998
# Epoch 10/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8385 - MSE: 0.8812
# Epoch 11/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.8539 - MSE: 0.8460
# Epoch 12/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.8596 - MSE: 0.8280
# Epoch 13/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.8387 - MSE: 0.8105
# Epoch 14/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.8586 - MSE: 0.8088
# Epoch 15/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.8593 - MSE: 0.8183
# Epoch 16/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.8328 - MSE: 0.8071
# Epoch 17/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.8289 - MSE: 0.7850
# Epoch 18/40
# 6400/6400 [==============================] - 3s 522us/sample - loss: 0.8540 - MSE: 0.8070
# Epoch 19/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8169 - MSE: 0.7881
# Epoch 20/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.8287 - MSE: 0.7884
# Epoch 21/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8794 - MSE: 0.7990
# Epoch 22/40
# 6400/6400 [==============================] - 3s 521us/sample - loss: 0.9472 - MSE: 0.8068
# Epoch 23/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.8964 - MSE: 0.7871
# Epoch 24/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.8847 - MSE: 0.7932
# Epoch 25/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.8873 - MSE: 0.7725
# Epoch 26/40
# 6400/6400 [==============================] - 3s 523us/sample - loss: 0.8854 - MSE: 0.7560
# Epoch 27/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.8212 - MSE: 0.7378
# Epoch 28/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.7987 - MSE: 0.7344
# Epoch 29/40
# 6400/6400 [==============================] - 3s 523us/sample - loss: 0.8018 - MSE: 0.7471
# Epoch 30/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8134 - MSE: 0.7246
# Epoch 31/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.7974 - MSE: 0.7185
# Epoch 32/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.8191 - MSE: 0.7314
# Epoch 33/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.8121 - MSE: 0.7111
# Epoch 34/40
# 6400/6400 [==============================] - 3s 523us/sample - loss: 0.8115 - MSE: 0.7123
# Epoch 35/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.7851 - MSE: 0.7027
# Epoch 36/40
# 6400/6400 [==============================] - 3s 522us/sample - loss: 0.7927 - MSE: 0.6923
# Epoch 37/40
# 6400/6400 [==============================] - 3s 524us/sample - loss: 0.8026 - MSE: 0.6716
# Epoch 38/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.7923 - MSE: 0.6803
# Epoch 39/40
# 6400/6400 [==============================] - 3s 523us/sample - loss: 0.7985 - MSE: 0.6694
# Epoch 40/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.7852 - MSE: 0.6787
# [CV]  batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.2, epochs=40, l2_reg=0.01, score=(train=0.718, test=0.807), total= 2.3min
# [CV] batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.2, epochs=40, l2_reg=0.01
# Train on 6400 samples
# Epoch 1/40
# 6400/6400 [==============================] - 5s 724us/sample - loss: 1.7172 - MSE: 2.4587
# Epoch 2/40
# 6400/6400 [==============================] - 3s 530us/sample - loss: 1.1478 - MSE: 1.2469
# Epoch 3/40
# 6400/6400 [==============================] - 3s 529us/sample - loss: 1.0139 - MSE: 1.1021
# Epoch 4/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.9726 - MSE: 1.0338
# Epoch 5/40
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.9313 - MSE: 1.0185
# Epoch 6/40
# 6400/6400 [==============================] - 3s 531us/sample - loss: 0.8720 - MSE: 0.9870
# Epoch 7/40
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.8755 - MSE: 0.9769
# Epoch 8/40
# 6400/6400 [==============================] - 3s 531us/sample - loss: 0.8875 - MSE: 0.9612
# Epoch 9/40
# 6400/6400 [==============================] - 3s 531us/sample - loss: 0.8532 - MSE: 0.9064
# Epoch 10/40
# 6400/6400 [==============================] - 3s 531us/sample - loss: 0.8843 - MSE: 0.8927
# Epoch 11/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.8620 - MSE: 0.8704
# Epoch 12/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.8631 - MSE: 0.8667
# Epoch 13/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.8436 - MSE: 0.8558
# Epoch 14/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.8335 - MSE: 0.8408
# Epoch 15/40
# 6400/6400 [==============================] - 3s 531us/sample - loss: 0.8639 - MSE: 0.8438
# Epoch 16/40
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.8950 - MSE: 0.8290
# Epoch 17/40
# 6400/6400 [==============================] - 3s 531us/sample - loss: 0.8913 - MSE: 0.8143
# Epoch 18/40
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.8799 - MSE: 0.8087
# Epoch 19/40
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8645 - MSE: 0.8258
# Epoch 20/40
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.8660 - MSE: 0.8306
# Epoch 21/40
# 6400/6400 [==============================] - 3s 530us/sample - loss: 0.8545 - MSE: 0.7951
# Epoch 22/40
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.8622 - MSE: 0.7737
# Epoch 23/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.8473 - MSE: 0.7974
# Epoch 24/40
# 6400/6400 [==============================] - 3s 532us/sample - loss: 0.8376 - MSE: 0.7972
# Epoch 25/40
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.8211 - MSE: 0.7732
# Epoch 26/40
# 6400/6400 [==============================] - 3s 530us/sample - loss: 0.8201 - MSE: 0.7760
# Epoch 27/40
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.8825 - MSE: 0.7790
# Epoch 28/40
# 6400/6400 [==============================] - 3s 531us/sample - loss: 0.8744 - MSE: 0.7525
# Epoch 29/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.8675 - MSE: 0.7474
# Epoch 30/40
# 6400/6400 [==============================] - 3s 530us/sample - loss: 0.8310 - MSE: 0.7322
# Epoch 31/40
# 6400/6400 [==============================] - 3s 530us/sample - loss: 0.8696 - MSE: 0.7362
# Epoch 32/40
# 6400/6400 [==============================] - 3s 531us/sample - loss: 0.7990 - MSE: 0.7181
# Epoch 33/40
# 6400/6400 [==============================] - 3s 532us/sample - loss: 0.8198 - MSE: 0.7114
# Epoch 34/40
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.8408 - MSE: 0.7394
# Epoch 35/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.8221 - MSE: 0.7231
# Epoch 36/40
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.8393 - MSE: 0.7248
# Epoch 37/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.8058 - MSE: 0.7073
# Epoch 38/40
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.8079 - MSE: 0.6955
# Epoch 39/40
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.8458 - MSE: 0.7109
# Epoch 40/40
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.7949 - MSE: 0.7358
# [CV]  batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.2, epochs=40, l2_reg=0.01, score=(train=0.732, test=0.779), total= 2.3min
# [CV] batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.4, epochs=25, l2_reg=0.001
# Train on 6400 samples
# Epoch 1/25
# 6400/6400 [==============================] - 5s 806us/sample - loss: 1.3222 - MSE: 3.0812
# Epoch 2/25
# 6400/6400 [==============================] - 3s 529us/sample - loss: 1.0329 - MSE: 1.7024
# Epoch 3/25
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.9613 - MSE: 1.3655
# Epoch 4/25
# 6400/6400 [==============================] - 3s 530us/sample - loss: 0.9158 - MSE: 1.2271
# Epoch 5/25
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.8829 - MSE: 1.0747
# Epoch 6/25
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.8543 - MSE: 0.9862
# Epoch 7/25
# 6400/6400 [==============================] - 3s 542us/sample - loss: 0.8343 - MSE: 0.9284
# Epoch 8/25
# 6400/6400 [==============================] - 4s 579us/sample - loss: 0.8092 - MSE: 0.8732
# Epoch 9/25
# 6400/6400 [==============================] - 4s 571us/sample - loss: 0.7945 - MSE: 0.8182
# Epoch 10/25
# 6400/6400 [==============================] - 3s 540us/sample - loss: 0.7858 - MSE: 0.8183
# Epoch 11/25
# 6400/6400 [==============================] - 3s 540us/sample - loss: 0.7692 - MSE: 0.7803
# Epoch 12/25
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.7853 - MSE: 0.7720
# Epoch 13/25
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.7808 - MSE: 0.7552
# Epoch 14/25
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.7925 - MSE: 0.7443
# Epoch 15/25
# 6400/6400 [==============================] - 3s 531us/sample - loss: 0.7705 - MSE: 0.7158
# Epoch 16/25
# 6400/6400 [==============================] - 3s 528us/sample - loss: 0.7678 - MSE: 0.7012
# Epoch 17/25
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.7551 - MSE: 0.6767
# Epoch 18/25
# 6400/6400 [==============================] - 3s 531us/sample - loss: 0.7689 - MSE: 0.6698
# Epoch 19/25
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.7631 - MSE: 0.6654
# Epoch 20/25
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.7699 - MSE: 0.6988
# Epoch 21/25
# 6400/6400 [==============================] - 3s 527us/sample - loss: 0.7555 - MSE: 0.6546
# Epoch 22/25
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.7604 - MSE: 0.6500
# Epoch 23/25
# 6400/6400 [==============================] - 3s 525us/sample - loss: 0.7655 - MSE: 0.6583
# Epoch 24/25
# 6400/6400 [==============================] - 3s 529us/sample - loss: 0.7592 - MSE: 0.6649
# Epoch 25/25
# 6400/6400 [==============================] - 3s 530us/sample - loss: 0.7609 - MSE: 0.6299
# [CV]  batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.4, epochs=25, l2_reg=0.001, score=(train=1.096, test=1.174), total= 1.5min
# [CV] batch_norm=True, batch_size=32, conv_layer_sizes=[16, 16], dense_layer_size=64, dropout=0.4, epochs=25, l2_reg=0.001
# Train on 6400 samples
# Epoch 1/25
# 6400/6400 [==============================] - 5s 758us/sample - loss: 1.4510 - MSE: 4.5694
# Epoch 2/25
# 6400/6400 [==============================] - 3s 529us/sample - loss: 1.0467 - MSE: 1.6800
# Epoch 3/25
# 6400/6400 [==============================] - 3s 526us/sample - loss: 0.9835 - MSE: 1.4325
# Epoch 4/25
# 6400/6400 [==============================] - 3s 530us/sample - loss: 0.9205 - MSE: 1.2400
# Epoch 5/25
# ...
#     'dense_layer_size': 128,
#     'dropout': 0.4,
#     'epochs': 25,
#     'l2_reg': 0.001},
#    {'batch_norm': True,
#     'batch_size': 32,
#     'conv_layer_sizes': [32, 32],
#     'dense_layer_size': 128,
#     'dropout': 0.4,
#     'epochs': 25,
#     'l2_reg': 0.01},
#    {'batch_norm': True,
#     'batch_size': 32,
#     'conv_layer_sizes': [32, 32],
#     'dense_layer_size': 128,
#     'dropout': 0.4,
#     'epochs': 40,
#     'l2_reg': 0.001},
#    {'batch_norm': True,
#     'batch_size': 32,
#     'conv_layer_sizes': [32, 32],
#     'dense_layer_size': 128,
#     'dropout': 0.4,
#     'epochs': 40,
#     'l2_reg': 0.01},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [16, 16],
#     'dense_layer_size': 64,
#     'dropout': 0.2,
#     'epochs': 25,
#     'l2_reg': 0.001},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [16, 16],
#     'dense_layer_size': 64,
#     'dropout': 0.2,
#     'epochs': 25,
#     'l2_reg': 0.01},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [16, 16],
#     'dense_layer_size': 64,
#     'dropout': 0.2,
#     'epochs': 40,
#     'l2_reg': 0.001},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [16, 16],
#     'dense_layer_size': 64,
#     'dropout': 0.2,
#     'epochs': 40,
#     'l2_reg': 0.01},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [16, 16],
#     'dense_layer_size': 64,
#     'dropout': 0.4,
#     'epochs': 25,
#     'l2_reg': 0.001},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [16, 16],
#     'dense_layer_size': 64,
#     'dropout': 0.4,
#     'epochs': 25,
#     'l2_reg': 0.01},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [16, 16],
#     'dense_layer_size': 64,
#     'dropout': 0.4,
#     'epochs': 40,
#     'l2_reg': 0.001},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [16, 16],
#     'dense_layer_size': 64,
#     'dropout': 0.4,
#     'epochs': 40,
#     'l2_reg': 0.01},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [16, 16],
#     'dense_layer_size': 128,
#     'dropout': 0.2,
#     'epochs': 25,
#     'l2_reg': 0.001},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [16, 16],
#     'dense_layer_size': 128,
#     'dropout': 0.2,
#     'epochs': 25,
#     'l2_reg': 0.01},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [16, 16],
#     'dense_layer_size': 128,
#     'dropout': 0.2,
#     'epochs': 40,
#     'l2_reg': 0.001},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [16, 16],
#     'dense_layer_size': 128,
#     'dropout': 0.2,
#     'epochs': 40,
#     'l2_reg': 0.01},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [16, 16],
#     'dense_layer_size': 128,
#     'dropout': 0.4,
#     'epochs': 25,
#     'l2_reg': 0.001},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [16, 16],
#     'dense_layer_size': 128,
#     'dropout': 0.4,
#     'epochs': 25,
#     'l2_reg': 0.01},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [16, 16],
#     'dense_layer_size': 128,
#     'dropout': 0.4,
#     'epochs': 40,
#     'l2_reg': 0.001},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [16, 16],
#     'dense_layer_size': 128,
#     'dropout': 0.4,
#     'epochs': 40,
#     'l2_reg': 0.01},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [32, 32],
#     'dense_layer_size': 64,
#     'dropout': 0.2,
#     'epochs': 25,
#     'l2_reg': 0.001},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [32, 32],
#     'dense_layer_size': 64,
#     'dropout': 0.2,
#     'epochs': 25,
#     'l2_reg': 0.01},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [32, 32],
#     'dense_layer_size': 64,
#     'dropout': 0.2,
#     'epochs': 40,
#     'l2_reg': 0.001},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [32, 32],
#     'dense_layer_size': 64,
#     'dropout': 0.2,
#     'epochs': 40,
#     'l2_reg': 0.01},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [32, 32],
#     'dense_layer_size': 64,
#     'dropout': 0.4,
#     'epochs': 25,
#     'l2_reg': 0.001},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [32, 32],
#     'dense_layer_size': 64,
#     'dropout': 0.4,
#     'epochs': 25,
#     'l2_reg': 0.01},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [32, 32],
#     'dense_layer_size': 64,
#     'dropout': 0.4,
#     'epochs': 40,
#     'l2_reg': 0.001},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [32, 32],
#     'dense_layer_size': 64,
#     'dropout': 0.4,
#     'epochs': 40,
#     'l2_reg': 0.01},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [32, 32],
#     'dense_layer_size': 128,
#     'dropout': 0.2,
#     'epochs': 25,
#     'l2_reg': 0.001},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [32, 32],
#     'dense_layer_size': 128,
#     'dropout': 0.2,
#     'epochs': 25,
#     'l2_reg': 0.01},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [32, 32],
#     'dense_layer_size': 128,
#     'dropout': 0.2,
#     'epochs': 40,
#     'l2_reg': 0.001},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [32, 32],
#     'dense_layer_size': 128,
#     'dropout': 0.2,
#     'epochs': 40,
#     'l2_reg': 0.01},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [32, 32],
#     'dense_layer_size': 128,
#     'dropout': 0.4,
#     'epochs': 25,
#     'l2_reg': 0.001},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [32, 32],
#     'dense_layer_size': 128,
#     'dropout': 0.4,
#     'epochs': 25,
#     'l2_reg': 0.01},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [32, 32],
#     'dense_layer_size': 128,
#     'dropout': 0.4,
#     'epochs': 40,
#     'l2_reg': 0.001},
#    {'batch_norm': False,
#     'batch_size': 32,
#     'conv_layer_sizes': [32, 32],
#     'dense_layer_size': 128,
#     'dropout': 0.4,
#     'epochs': 40,
#     'l2_reg': 0.01}],
#   'split0_test_score': array([0.84976387, 0.88405708, 1.09684077, 4.81254248, 1.17366202,
#          0.94711685, 0.63869331, 0.95657584, 0.71867062, 0.65709292,
#          1.03743246, 0.66595156, 1.04686592, 0.66552441, 1.14646775,
#          0.92085767, 0.75091142, 0.87884381, 0.91315771, 0.71487041,
#          0.61244359, 0.59455441, 0.75350982, 1.12115763, 0.69036002,
#          0.76786888, 0.68774754, 1.54312143, 1.00564723, 1.00899898,
#          1.21165066, 0.86486711, 0.62347082, 0.56974153, 0.62884477,
#          0.57049133, 0.59248988, 0.58276355, 0.5972544 , 0.61035678,
#          0.62186865, 0.56516943, 0.60623748, 0.56237598, 0.59017975,
#          0.5707368 , 0.59237697, 0.58738374, 0.61663762, 0.58366096,
#          0.62237181, 0.57367864, 0.6207345 , 0.59154239, 0.61295914,
#          0.56803427, 0.62631417, 0.56675075, 0.60593576, 0.57622743,
#          0.58385942, 0.57263113, 0.6014562 , 0.56890022]),
#   'split1_test_score': array([1.18197148, 0.88964667, 0.9884388 , 0.80709543, 1.56301843,
#          0.62131891, 1.01646967, 0.67258137, 0.71007348, 1.00944489,
#          0.75467305, 1.88325603, 1.04606985, 0.921954  , 0.71255034,
#          0.80857799, 1.24780554, 0.72849138, 0.6463961 , 1.21169205,
#          1.00244212, 1.23128972, 1.39418118, 0.69265483, 0.8657227 ,
#          0.78516046, 0.7450474 , 0.94661609, 0.64710976, 0.66767519,
#          0.98620672, 0.65646943, 0.64485602, 0.59772155, 0.63941061,
#          0.59036232, 0.6328555 , 0.61182351, 0.61046156, 0.58110384,
#          0.64713053, 0.59346947, 0.66274153, 0.58887001, 0.61156123,
#          0.60808433, 0.6231162 , 0.58385406, 0.64041868, 0.59989691,
#          0.64628187, 0.59291777, 0.6234038 , 0.60582653, 0.61730981,
#          0.64169297, 0.63489844, 0.57776697, 0.65909113, 0.57796465,
#          0.61146996, 0.58556453, 0.63078712, 0.58513128]),
#   'split2_test_score': array([1.03735794, 0.69978785, 1.03737648, 0.77872455, 0.63931576,
#          0.70160122, 2.91857959, 1.26575263, 0.79514599, 0.74788071,
#          0.68691673, 0.74147458, 0.77398405, 0.83558286, 0.65251278,
#          0.74918324, 0.83453476, 0.72208536, 0.6832639 , 0.66930571,
#          0.91538995, 0.88338281, 2.78966527, 0.66265316, 0.72726791,
#          0.73712193, 1.16416088, 0.8544358 , 0.87145569, 0.74737319,
#          0.85962531, 0.68648356, 0.62155168, 0.57952899, 0.63240389,
#          0.56839642, 0.60816575, 0.63439981, 0.61286285, 0.57302679,
#          0.63833237, 0.5753695 , 0.63956304, 0.5806354 , 0.58696109,
#          0.63284316, 0.58977155, 0.57519483, 0.63208857, 0.67897026,
#          0.62387299, 0.585648  , 0.60104042, 0.60578695, 0.60997884,
#          0.58124017, 0.63654677, 0.59512688, 0.63354531, 0.57386207,
#          0.5911472 , 0.58186858, 0.60610794, 0.5769334 ]),
#   'mean_test_score': array([1.0230311 , 0.8244972 , 1.04088535, 2.13278749, 1.12533207,
#          0.75667899, 1.52458086, 0.96496995, 0.7412967 , 0.80480617,
#          0.82634075, 1.09689406, 0.95563994, 0.80768709, 0.83717695,
#          0.8262063 , 0.94441724, 0.77647351, 0.7476059 , 0.86528939,
#          0.84342522, 0.90307565, 1.64578542, 0.82548854, 0.76111688,
#          0.76338376, 0.86565194, 1.11472444, 0.84140423, 0.80801579,
#          1.01916089, 0.73594003, 0.62995951, 0.58233069, 0.63355309,
#          0.57641669, 0.61117038, 0.60966229, 0.6068596 , 0.58816247,
#          0.63577718, 0.5780028 , 0.63618068, 0.5772938 , 0.59623402,
#          0.6038881 , 0.60175491, 0.58214421, 0.62971495, 0.62084271,
#          0.63084223, 0.58408147, 0.61505957, 0.60105196, 0.61341593,
#          0.59698914, 0.63258646, 0.57988153, 0.6328574 , 0.57601805,
#          0.59549219, 0.58002142, 0.61278375, 0.5769883 ]),
#   'std_test_score': array([1.36001026e-01, 8.82123443e-02, 4.43244175e-02, 1.89490833e+00,
#          3.78645387e-01, 1.38591111e-01, 9.97698382e-01, 2.42233881e-01,
#          3.82386123e-02, 1.49372821e-01, 1.51805826e-01, 5.56896040e-01,
#          1.28450522e-01, 1.06529067e-01, 2.20070780e-01, 7.11856526e-02,
#          2.17227316e-01, 7.24339542e-02, 1.18026433e-01, 2.45648985e-01,
#          1.67150440e-01, 2.60318801e-01, 8.50082652e-01, 2.09428081e-01,
#          7.54865641e-02, 1.98664233e-02, 2.12369975e-01, 3.05251033e-01,
#          1.47906719e-01, 1.45793518e-01, 1.45590625e-01, 9.19849826e-02,
#          1.05625237e-02, 1.15933181e-02, 4.38936027e-03, 9.89806643e-03,
#          1.66155860e-02, 2.11357329e-02, 6.86229068e-03, 1.60364245e-02,
#          1.04701937e-02, 1.17025283e-02, 2.31913351e-02, 1.10712287e-02,
#          1.09173378e-02, 2.55278441e-02, 1.51421204e-02, 5.12087801e-03,
#          9.85258788e-03, 4.16334065e-02, 1.09346641e-02, 7.93206975e-03,
#          9.97275738e-03, 6.72429970e-03, 3.01023733e-03, 3.20668427e-02,
#          4.48593938e-03, 1.16806062e-02, 2.17060411e-02, 1.68140103e-03,
#          1.16831689e-02, 5.43919206e-03, 1.28711716e-02, 6.62641350e-03]),
#   'rank_test_score': array([ 8, 22,  7,  1,  4, 29,  3, 10, 31, 25, 19,  6, 11, 24, 18, 20, 12,
#          26, 30, 15, 16, 13,  2, 21, 28, 27, 14,  5, 17, 23,  9, 32, 39, 56,
#          35, 63, 45, 46, 47, 54, 34, 60, 33, 61, 52, 48, 49, 57, 40, 41, 38,
#          55, 42, 50, 43, 51, 37, 59, 36, 64, 53, 58, 44, 62]),
#   'split0_train_score': array([0.79108028, 0.84037708, 1.04298436, 4.80194145, 1.0956022 ,
#          0.95583307, 0.44077471, 0.95584605, 0.70246348, 0.67030508,
#          0.92554102, 0.66065955, 0.99372812, 0.68122804, 1.1525452 ,
#          0.92922375, 0.64878605, 0.89032304, 0.75352801, 0.71305537,
#          0.48575631, 0.58796227, 0.67839811, 1.13251976, 0.47171486,
#          0.78674439, 0.44025859, 1.52751446, 0.98680538, 1.02132301,
#          1.2015352 , 0.87532431, 0.38150007, 0.56258127, 0.31688839,
#          0.55145078, 0.47767279, 0.5894528 , 0.39695854, 0.59980534,
#          0.40827627, 0.55091634, 0.33011717, 0.53716042, 0.47603255,
#          0.57593354, 0.42288843, 0.58768838, 0.35948582, 0.56785368,
#          0.30467708, 0.52619628, 0.45915768, 0.57605402, 0.38159278,
#          0.5524646 , 0.37447094, 0.54764095, 0.33722208, 0.54588277,
#          0.45446378, 0.57721913, 0.40061277, 0.56096195]),
#   'split1_train_score': array([1.11719192, 0.86097536, 0.76450678, 0.71771596, 1.53428194,
#          0.58974978, 0.95442172, 0.6386802 , 0.45054744, 0.98662779,
#          0.53883061, 1.89103208, 0.98697642, 0.90319921, 0.59509668,
#          0.78599232, 1.17702134, 0.70532745, 0.40006388, 1.18962386,
#          0.90841264, 1.20532841, 1.33251257, 0.66328746, 0.72185372,
#          0.76830197, 0.48212623, 0.92535228, 0.547361  , 0.65595835,
#          0.89980408, 0.6426646 , 0.40433518, 0.5639409 , 0.34041782,
#          0.53876833, 0.47777078, 0.59154571, 0.41029717, 0.54254091,
#          0.43007083, 0.56780345, 0.34893175, 0.55740924, 0.48606773,
#          0.58885018, 0.43871801, 0.56621507, 0.3825159 , 0.55945685,
#          0.30886611, 0.49822221, 0.44672399, 0.58207635, 0.39418393,
#          0.60171484, 0.39350234, 0.54736943, 0.33016803, 0.52660627,
#          0.46775709, 0.56520261, 0.40422848, 0.55708937]),
#   'split2_train_score': array([0.95483663, 0.6851875 , 0.97755874, 0.73187794, 0.50274184,
#          0.67899602, 2.94394783, 1.26947302, 0.64468925, 0.73636194,
#          0.46139704, 0.72483478, 0.67183576, 0.83549023, 0.44741453,
#          0.74312286, 0.69114233, 0.70223907, 0.44176704, 0.61683216,
#          0.86622842, 0.87136745, 2.8482919 , 0.63374515, 0.45310643,
#          0.7222124 , 1.04749526, 0.85705447, 0.76833131, 0.74176458,
#          0.78012642, 0.67677433, 0.37782176, 0.551239  , 0.32004651,
#          0.53704309, 0.48139418, 0.60930278, 0.42633251, 0.55971931,
#          0.41228378, 0.56461063, 0.34413815, 0.54678605, 0.49408482,
#          0.61971092, 0.43864105, 0.56635606, 0.38393834, 0.67080681,
#          0.32962773, 0.52232571, 0.45452489, 0.58248435, 0.397339  ,
#          0.55227418, 0.37692782, 0.58138406, 0.32657877, 0.53560411,
#          0.50194951, 0.57104769, 0.3825996 , 0.55724101]),
#   'mean_train_score': array([0.95436961, 0.79551331, 0.92834996, 2.08384512, 1.04420866,
#          0.74152629, 1.44638142, 0.95466642, 0.59923339, 0.79776494,
#          0.64192289, 1.09217547, 0.8841801 , 0.80663916, 0.73168547,
#          0.81944631, 0.83898324, 0.76596319, 0.53178631, 0.83983713,
#          0.75346579, 0.88821938, 1.61973419, 0.80985079, 0.54889167,
#          0.75908625, 0.65662669, 1.10330707, 0.76749923, 0.80634865,
#          0.96048856, 0.73158774, 0.38788567, 0.55925373, 0.32578424,
#          0.54242073, 0.47894592, 0.5967671 , 0.41119607, 0.56735519,
#          0.41687696, 0.56111014, 0.34106235, 0.54711857, 0.48539504,
#          0.59483155, 0.43341583, 0.57341984, 0.37531335, 0.59937244,
#          0.31439031, 0.5155814 , 0.45346885, 0.58020491, 0.39103857,
#          0.56881788, 0.3816337 , 0.55879815, 0.33132296, 0.53603105,
#          0.47472346, 0.57115648, 0.39581362, 0.55843078]),
#   'std_train_score': array([1.33134930e-01, 7.84640540e-02, 1.18893704e-01, 1.92199304e+00,
#          4.22689572e-01, 1.55856280e-01, 1.07950210e+00, 2.57521443e-01,
#          1.07750017e-01, 1.36241844e-01, 2.03024504e-01, 5.65484176e-01,
#          1.50175420e-01, 9.28873460e-02, 3.03638700e-01, 7.95728657e-02,
#          2.39653682e-01, 8.79447332e-02, 1.57716678e-01, 2.50436680e-01,
#          1.90080950e-01, 2.52320205e-01, 9.08838807e-01, 2.28479958e-01,
#          1.22538353e-01, 2.71390405e-02, 2.76913828e-01, 3.01253026e-01,
#          1.79403378e-01, 1.55993935e-01, 1.77310077e-01, 1.02586606e-01,
#          1.17280924e-02, 5.69438275e-03, 1.04275158e-02, 6.42393751e-03,
#          1.73164716e-03, 8.90515237e-03, 1.20087050e-02, 2.39935240e-02,
#          9.47184162e-03, 7.32501189e-03, 7.98300145e-03, 8.26988789e-03,
#          7.38514072e-03, 1.83656808e-02, 7.44406407e-03, 1.00895481e-02,
#          1.12068126e-02, 5.06279076e-02, 1.09093641e-02, 1.23760890e-02,
#          5.13066298e-03, 2.93984256e-03, 6.80224566e-03, 2.32617986e-02,
#          8.45212155e-03, 1.59710360e-02, 4.42119345e-03, 7.87538308e-03,
#          2.00020218e-02, 4.90632589e-03, 9.45960241e-03, 1.79088121e-03])},
#  'n_splits_': 3}

# %%
best2.cv_results_['mean_test_score']
# Out:
# array([1.0230311 , 0.8244972 , 1.04088535, 2.13278749, 1.12533207,
#        0.75667899, 1.52458086, 0.96496995, 0.7412967 , 0.80480617,
#        0.82634075, 1.09689406, 0.95563994, 0.80768709, 0.83717695,
#        0.8262063 , 0.94441724, 0.77647351, 0.7476059 , 0.86528939,
#        0.84342522, 0.90307565, 1.64578542, 0.82548854, 0.76111688,
#        0.76338376, 0.86565194, 1.11472444, 0.84140423, 0.80801579,
#        1.01916089, 0.73594003, 0.62995951, 0.58233069, 0.63355309,
#        0.57641669, 0.61117038, 0.60966229, 0.6068596 , 0.58816247,
#        0.63577718, 0.5780028 , 0.63618068, 0.5772938 , 0.59623402,
#        0.6038881 , 0.60175491, 0.58214421, 0.62971495, 0.62084271,
#        0.63084223, 0.58408147, 0.61505957, 0.60105196, 0.61341593,
#        0.59698914, 0.63258646, 0.57988153, 0.6328574 , 0.57601805,
#        0.59549219, 0.58002142, 0.61278375, 0.5769883 ])

# %%
#Pulling some pretty graphs for training

acc = history.history['MSE']

loss=history.history['loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.legend(loc='lower right')
plt.title('Training Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.legend(loc='upper right')
plt.title('Training Loss')
plt.show()
